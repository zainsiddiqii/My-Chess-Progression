# %%
import pandas as pd
import re
from datetime import datetime

# %%
earlier_games = pd.read_csv("early_career_games.csv")
later_games = pd.read_csv("late_career_games.csv")

games = pd.concat([earlier_games, later_games])

games.head()
# Out:
#    Unnamed: 0.1 Unnamed: 0                                      Players
# 0             0     10 min    zainsiddiqii  (557)  methburger682  (356)  \
# 1             1     10 min   JimenaGallardo  (438)  zainsiddiqii  (643)
# 2             2     10 min  DanielBrown1974  (577)  zainsiddiqii  (531)
# 3             3     10 min          zainsiddiqii  (625)  RRR0007  (615)
# 4             4     10 min         zainsiddiqii  (564)  prune131  (639)
#
#   Result    Accuracy  Moves          Date  Unnamed: 6
# 0   1  0  42.3  57.6     62   Dec 6, 2020         NaN  \
# 1   0  1  77.7  64.7     40   Dec 9, 2020         NaN
# 2   1  0  76.4  58.3     25   Dec 9, 2020         NaN
# 3   1  0  81.4  77.5     64   Dec 9, 2020         NaN
# 4   0  1  31.6  55.5     12  Dec 10, 2020         NaN
#
#                                     game_link
# 0  https://www.chess.com/game/live/5900312365
# 1  https://www.chess.com/game/live/5922717305
# 2  https://www.chess.com/game/live/5923131073
# 3  https://www.chess.com/game/live/5923181350
# 4  https://www.chess.com/game/live/5927374018

# %%
games.isna().sum()
# Out:
# Unnamed: 0.1       0
# Unnamed: 0         0
# Players            0
# Result             0
# Accuracy          45
# Moves              0
# Date               0
# Unnamed: 6      9900
# game_link          0
# dtype: int64

# %%
games.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0       object
# Players          object
# Result           object
# Accuracy         object
# Moves             int64
# Date             object
# Unnamed: 6      float64
# game_link        object
# dtype: object

# %%
games.drop(columns = ["Unnamed: 0.1", "Unnamed: 6"], inplace = True)
games.rename(columns = {"Unnamed: 0": "time_control"}, inplace = True)
games.columns = games.columns.str.lower()
for col in games.columns:
    if games[col].dtype == 'object':
        games[col].str.strip()
games.head()
# Out:
#   time_control                                      players result
# 0       10 min    zainsiddiqii  (557)  methburger682  (356)   1  0  \
# 1       10 min   JimenaGallardo  (438)  zainsiddiqii  (643)   0  1
# 2       10 min  DanielBrown1974  (577)  zainsiddiqii  (531)   1  0
# 3       10 min          zainsiddiqii  (625)  RRR0007  (615)   1  0
# 4       10 min         zainsiddiqii  (564)  prune131  (639)   0  1
#
#      accuracy  moves          date                                   game_link
# 0  42.3  57.6     62   Dec 6, 2020  https://www.chess.com/game/live/5900312365
# 1  77.7  64.7     40   Dec 9, 2020  https://www.chess.com/game/live/5922717305
# 2  76.4  58.3     25   Dec 9, 2020  https://www.chess.com/game/live/5923131073
# 3  81.4  77.5     64   Dec 9, 2020  https://www.chess.com/game/live/5923181350
# 4  31.6  55.5     12  Dec 10, 2020  https://www.chess.com/game/live/5927374018

# %%
print(games.time_control.value_counts())
# Out:
# time_control
# 5 min     4418
# 10 min    2788
# 3 min     2550
# 5|5         81
# 1 min       23
# 3|2         20
# 30 min       7
# 2|1          6
# 15|10        5
# 20 min       2
# Name: count, dtype: int64

# %%
games.time_control.replace(["5 min", "10 min", "3 min", "1 min", "30 min", "20 min"],
                           ["5|0", "10|0", "3|0", "1|0", "30|0", "20|0"],
                           inplace = True)
games.time_control = games.time_control.str.replace("|", "+")
games.time_control.value_counts()
# Out:
# time_control
# 5+0      4418
# 10+0     2788
# 3+0      2550
# 5+5        81
# 1+0        23
# 3+2        20
# 30+0        7
# 2+1         6
# 15+10       5
# 20+0        2
# Name: count, dtype: int64

# %%
games["time_format"] = games.time_control.apply(lambda x: "Rapid" if len(x.split("+")[0]) == 2
                                                else ("Blitz" if (int(x[0]) >= 3) & (int(x[0]) <=5)
                                                else "Bullet"))
games.time_format.value_counts()
# Out:
# time_format
# Blitz     7069
# Rapid     2802
# Bullet      29
# Name: count, dtype: int64

# %%
games["colour"] = games.players.apply(lambda x: "White" if x.split(" ")[0] == "zainsiddiqii" else "Black")
games.colour.value_counts()
# Out:
# colour
# White    4968
# Black    4932
# Name: count, dtype: int64

# %%
games["my_rating"] = games.apply(lambda x: x["players"].split(" ")[2] if x["colour"] == "White"
                                 else x["players"].split(" ")[-1],
                                 axis = 1).str.replace("(", "").str.replace(")", "")

games["opponent_rating"] = games.apply(lambda x: x["players"].split(" ")[-1] if x["colour"] == "White"
                                       else x["players"].split(" ")[2],
                                       axis = 1).str.replace("(", "").str.replace(")", "")

games["opponent"] = games.apply(lambda x: x["players"].split(" ")[0] if x["colour"] == "Black"
                                else x["players"].split(" ")[4],
                                axis = 1)
games.head()
# Out:
#   time_control                                      players result
# 0         10+0    zainsiddiqii  (557)  methburger682  (356)   1  0  \
# 1         10+0   JimenaGallardo  (438)  zainsiddiqii  (643)   0  1
# 2         10+0  DanielBrown1974  (577)  zainsiddiqii  (531)   1  0
# 3         10+0          zainsiddiqii  (625)  RRR0007  (615)   1  0
# 4         10+0         zainsiddiqii  (564)  prune131  (639)   0  1
#
#      accuracy  moves          date
# 0  42.3  57.6     62   Dec 6, 2020  \
# 1  77.7  64.7     40   Dec 9, 2020
# 2  76.4  58.3     25   Dec 9, 2020
# 3  81.4  77.5     64   Dec 9, 2020
# 4  31.6  55.5     12  Dec 10, 2020
#
#                                     game_link time_format colour my_rating
# 0  https://www.chess.com/game/live/5900312365       Rapid  White       557  \
# 1  https://www.chess.com/game/live/5922717305       Rapid  Black       643
# 2  https://www.chess.com/game/live/5923131073       Rapid  Black       531
# 3  https://www.chess.com/game/live/5923181350       Rapid  White       625
# 4  https://www.chess.com/game/live/5927374018       Rapid  White       564
#
#   opponent_rating         opponent
# 0             356    methburger682
# 1             438   JimenaGallardo
# 2             577  DanielBrown1974
# 3             615          RRR0007
# 4             639         prune131

# %%
day = games.date.dt.day
print(day)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22216\1170743683.py in <module>
# ----> 1 day = games.date.dt.day
#       2 print(day)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     578             return PeriodProperties(data, orig)
#     579
# --> 580         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
games["win"] = games.apply(lambda x: True if (x["colour"] == "White" and x["result"][0] == "1")
                           or (x["colour"] == "Black" and x["result"][-1] == "1") else False,
                           axis = 1)
games.head()
# Out:
#   time_control                                      players result
# 0         10+0    zainsiddiqii  (557)  methburger682  (356)   1  0  \
# 1         10+0   JimenaGallardo  (438)  zainsiddiqii  (643)   0  1
# 2         10+0  DanielBrown1974  (577)  zainsiddiqii  (531)   1  0
# 3         10+0          zainsiddiqii  (625)  RRR0007  (615)   1  0
# 4         10+0         zainsiddiqii  (564)  prune131  (639)   0  1
#
#      accuracy  moves          date
# 0  42.3  57.6     62   Dec 6, 2020  \
# 1  77.7  64.7     40   Dec 9, 2020
# 2  76.4  58.3     25   Dec 9, 2020
# 3  81.4  77.5     64   Dec 9, 2020
# 4  31.6  55.5     12  Dec 10, 2020
#
#                                     game_link time_format colour my_rating
# 0  https://www.chess.com/game/live/5900312365       Rapid  White       557  \
# 1  https://www.chess.com/game/live/5922717305       Rapid  Black       643
# 2  https://www.chess.com/game/live/5923131073       Rapid  Black       531
# 3  https://www.chess.com/game/live/5923181350       Rapid  White       625
# 4  https://www.chess.com/game/live/5927374018       Rapid  White       564
#
#   opponent_rating         opponent    win
# 0             356    methburger682   True
# 1             438   JimenaGallardo   True
# 2             577  DanielBrown1974  False
# 3             615          RRR0007   True
# 4             639         prune131  False

# %%
games.date = pd.to_datetime(games.date, format='%b %d, %Y')
games.date = games["date"].dt.strftime('%d-%m-%Y')
games.head()
# Out:
#   time_control                                      players result
# 0         10+0    zainsiddiqii  (557)  methburger682  (356)   1  0  \
# 1         10+0   JimenaGallardo  (438)  zainsiddiqii  (643)   0  1
# 2         10+0  DanielBrown1974  (577)  zainsiddiqii  (531)   1  0
# 3         10+0          zainsiddiqii  (625)  RRR0007  (615)   1  0
# 4         10+0         zainsiddiqii  (564)  prune131  (639)   0  1
#
#      accuracy  moves        date                                   game_link
# 0  42.3  57.6     62  06-12-2020  https://www.chess.com/game/live/5900312365  \
# 1  77.7  64.7     40  09-12-2020  https://www.chess.com/game/live/5922717305
# 2  76.4  58.3     25  09-12-2020  https://www.chess.com/game/live/5923131073
# 3  81.4  77.5     64  09-12-2020  https://www.chess.com/game/live/5923181350
# 4  31.6  55.5     12  10-12-2020  https://www.chess.com/game/live/5927374018
#
#   time_format colour my_rating opponent_rating         opponent    win
# 0       Rapid  White       557             356    methburger682   True
# 1       Rapid  Black       643             438   JimenaGallardo   True
# 2       Rapid  Black       531             577  DanielBrown1974  False
# 3       Rapid  White       625             615          RRR0007   True
# 4       Rapid  White       564             639         prune131  False

# %%
games.accuracy = games.accuracy.astype("string")
games["my_accuracy"] = games.apply(lambda x: x["accuracy"][:4] if x["colour"] == "White"
                                   else x["accuracy"][-4:],
                                   axis = 1)

games.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22216\1060604057.py in <module>
#       1 games.accuracy = games.accuracy.astype("string")
# ----> 2 games["my_accuracy"] = games.apply(lambda x: x["accuracy"][:4] if x["colour"] == "White"
#       3                                    else x["accuracy"][-4:],
#       4                                    axis = 1)
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9431             kwargs=kwargs,
#    9432         )
# -> 9433         return op.apply().__finalize__(self, method="apply")
#    9434
#    9435     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#     679
#     680     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     796
#     797     def apply_standard(self):
# --> 798         results, res_index = self.apply_series_generator()
#     799
#     800         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     812             for i, v in enumerate(series_gen):
#     813                 # ignore SettingWithCopy here in case the user mutates
# --> 814                 results[i] = self.f(v)
#     815                 if isinstance(results[i], ABCSeries):
#     816                     # If we have a view on v, we need to make a copy because
#
# ~\AppData\Local\Temp\ipykernel_22216\1060604057.py in <lambda>(x)
#       1 games.accuracy = games.accuracy.astype("string")
#       2 games["my_accuracy"] = games.apply(lambda x: x["accuracy"][:4] if x["colour"] == "White"
# ----> 3                                    else x["accuracy"][-4:],
#       4                                    axis = 1)
#       5
#
# TypeError: 'NAType' object is not subscriptable
